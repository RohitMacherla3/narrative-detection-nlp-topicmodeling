# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from itertools import chain
from collections import Counter
import string
import random
from itertools import islice
import json


import nltk
from nltk.corpus import stopwords
from nltk.util import ngrams
from transformers import pipeline
import pickle

# %%
email_data = pd.read_pickle('Email/emails_uni_bi_neg.pkl')

# %%
email_unigrams = email_data['unigrams']
email_bigrams = email_data['bigrams']

# %%
podcast_data = pd.read_pickle('Podcast/podcast_uni_bi_neg.pkl')

# %%
podcast_unigrams = podcast_data['unigrams']
podcast_bigrams = podcast_data['bigrams']

# %%
tv_data = pd.read_pickle('TV/TV_uni_bigrams.pkl')

# %%
tv_unigrams = tv_data['unigrams']
tv_bigrams = tv_data['bigrams']

# %%
total_frequencies = {}
for source_unigrams in [email_unigrams, podcast_unigrams, tv_unigrams]:
    for word, freq in source_unigrams.items():
        total_frequencies[word] = total_frequencies.get(word, 0) + freq

relative_frequencies = {}
for source, source_unigrams in [("emails", email_unigrams), ("podcasts", podcast_unigrams), ("tv", tv_unigrams)]:
    relative_frequencies[source] = {word: freq / total_frequencies[word] for word, freq in source_unigrams.items()}

unique_unigrams = {}
for source, source_relative_frequencies in relative_frequencies.items():
    keys = sorted(source_relative_frequencies.keys(), key=lambda x: source_relative_frequencies[x], reverse=True)[:200]
    unique_unigrams[source] = [(key, total_frequencies[key]) for key in keys]

# %%
unique_unigrams['emails']
# Out:
# [('͏', 258721),
#  ('dpwillis67gmailcom', 24331),
#  ('→', 13661),
#  ('͏͏', 7754),
#  ('todpwillis67gmailcom', 5388),
#  ('tounsubscribe', 4501),
#  ('endofmonth', 4367),
#  ('➞', 4352),
#  ('22314', 4094),
#  ('★', 3374),
#  ('yoursubscription', 3233),
#  ('endofquarter', 3084),
#  ('20003', 2796),
#  ('pleaseclick', 2513),
#  ('actionnetworkorg', 2461),
#  ('oraddress', 2461),
#  ('noncontribution', 2181),
#  ('candidatescommittee', 2139),
#  ('taxpurposes', 2103),
#  ('anymoreunsubscribe', 2040),
#  ('majoritypac', 2009),
#  ('grassrootssupporters', 1792),
#  ('donationwill', 1791),
#  ('paymentinformation', 1730),
#  ('pleaseunsubscribe', 1693),
#  ('22219', 1564),
#  ('page625', 1489),
#  ('88022', 1483),
#  ('32853', 1362),
#  ('box536926', 1255),
#  ('preferencespage625', 1248),
#  ('implyendorsement', 1242),
#  ('unsubscribefrom', 1220),
#  ('\u200b', 1199),
#  ('98104', 1192),
#  ('ouremails', 1185),
#  ('receiveemail', 1184),
#  ('caraveo', 1135),
#  ('inerror', 1112),
#  ('removeyourself', 1096),
#  ('ruinour', 1080),
#  ('❌', 1079),
#  ('averageonline', 1074),
#  ('throughimmediately', 1068),
#  ('contributionaccount', 1054),
#  ('democracydepends', 1053),
#  ('immediatelydonate', 1048),
#  ('yourpayment', 1043),
#  ('majoritybecause', 1035),
#  ('atteam', 1006),
#  ('03302', 995),
#  ('✅', 986),
#  ('autodialed', 960),
#  ('🚨', 954),
#  ('hereunsubscribe', 949),
#  ('noncontributionaccount', 945),
#  ('pacsnoncontribution', 945),
#  ('beforemidnight', 926),
#  ('corporationslabor', 920),
#  ('canunsubscribe', 910),
#  ('orgifts', 909),
#  ('thislink', 906),
#  ('longerreceive', 900),
#  ('majoritypacs', 899),
#  ('maggiefor', 897),
#  ('federalcontributions', 893),
#  ('allocationformula', 893),
#  ('iffollowing', 893),
#  ('unlimitedamount', 893),
#  ('21818', 876),
#  ('➔', 867),
#  ('skarlatos', 860),
#  ('33731', 857),
#  ('official2022', 816),
#  ('youchip', 811),
#  ('13570arlington', 781),
#  ('mailtoinfotimforohcom', 781),
#  ('campaignupdates', 776),
#  ('13401', 768),
#  ('personalizedgold', 766),
#  ('uptodateon', 765),
#  ('thatbelow', 764),
#  ('supportprivacy', 763),
#  ('congresspo', 748),
#  ('anyamount', 737),
#  ('13570', 730),
#  ('msgdataratesmayapply', 727),
#  ('requestfewer', 713),
#  ('fundraisingdeadline', 708),
#  ('scommittee', 701),
#  ('1547', 700),
#  ('ourfundraising', 695),
#  ('incmichael', 674),
#  ('120137', 673),
#  ('85750', 673),
#  ('8886061023', 661),
#  ('donateonce', 640),
#  ('actblueexpress', 632),
#  ('betofor', 628),
#  ('yourdonation', 626),
#  ('emailsanymoreunsubscribe', 615),
#  ('\u200b\u200b', 613),
#  ('trumptrainnews', 612),
#  ('\u200bpaid', 611),
#  ('darrigo', 609),
#  ('unitedemocrats', 608),
#  ('youvesaved', 597),
#  ('signatureheadshot', 596),
#  ('orcandidate', 596),
#  ('feweremails', 596),
#  ('endmessfreqmayvary', 596),
#  ('dedicatedmember', 595),
#  ('1john', 587),
#  ('freedomlovingpatriots', 585),
#  ('anotheramount', 584),
#  ('ohio44446', 581),
#  ('tcprivacy', 580),
#  ('topelosi', 580),
#  ('ourgrassroots', 579),
#  ('va07', 577),
#  ('⇒', 575),
#  ('textsto', 568),
#  ('nbsp', 568),
#  ('1beto', 565),
#  ('receivedthis', 560),
#  ('notdeductible', 554),
#  ('donaldjtrumpcomsave', 552),
#  ('27605', 543),
#  ('swhy', 543),
#  ('20002', 542),
#  ('15180washington', 542),
#  ('privacypolicy', 536),
#  ('mailingaddress', 528),
#  ('–and', 525),
#  ('ehasz', 520),
#  ('pitchin', 517),
#  ('statesclick', 511),
#  ('97127', 510),
#  ('27602', 507),
#  ('withactblue', 506),
#  ('15180', 494),
#  ('redistrictingcommittee', 492),
#  ('youdonate', 481),
#  ('emaillist', 481),
#  ('paramountconservativeconnect', 481),
#  ('immediatelycontribute', 472),
#  ('ascharitable', 471),
#  ('ouremail', 469),
#  ('50310', 469),
#  ('savedyour', 468),
#  ('icymi', 465),
#  ('fundraisinggoal', 462),
#  ('200031885', 456),
#  ('receivethese', 454),
#  ('thispreferences', 443),
#  ('27624', 440),
#  ('rightsreserved', 436),
#  ('arballo', 431),
#  ('ourrevolution', 427),
#  ('governorare', 425),
#  ('feenstra', 425),
#  ('––', 424),
#  ('30308', 423),
#  ('ongrassroots', 422),
#  ('stea102', 422),
#  ('6564', 421),
#  ('1stacey', 417),
#  ('allrights', 415),
#  ('89126', 409),
#  ('yourpreferences', 409),
#  ('27195', 404),
#  ('45206', 398),
#  ('sewashington', 396),
#  ('quaye', 395),
#  ('87125', 393),
#  ('2022icymi', 393),
#  ('oursenate', 390),
#  ('18326', 388),
#  ('inforoycoopercom', 380),
#  ('dpwillis67gmailcomcommunicating', 375),
#  ('icount', 374),
#  ('updateyour', 373),
#  ('6806', 368),
#  ('rosenfor', 367),
#  ('winninggrassroots', 366),
#  ('45401', 364),
#  ('20005united', 363),
#  ('30295', 359),
#  ('37203', 357),
#  ('unsubscribehere', 356),
#  ('➠', 354),
#  ('››', 352),
#  ('1charles', 352),
#  ('quartey', 349),
#  ('makki', 348),
#  ('87113', 347),
#  ('33303', 346),
#  ('85067', 346),
#  ('purposescontributions', 345),
#  ('19006', 344)]

# %%
unique_unigrams['podcasts']
# Out:
# [('it′s', 3145),
#  ('puretalkcom', 2370),
#  ('don′t', 1938),
#  ('that′s', 1894),
#  ('877444gold', 1625),
#  ('8773813811', 1592),
#  ('moink', 1410),
#  ('expressvpn', 1369),
#  ('i′m', 1339),
#  ('§§', 1338),
#  ('65532', 1220),
#  ('you′re', 1207),
#  ('they′re', 1184),
#  ('hometitlelockcom', 1159),
#  ('chumba', 1131),
#  ('betmgm', 1015),
#  ('we′re', 1001),
#  ('billoreillycom', 965),
#  ('levinforhillsdalecom', 954),
#  ('989898', 939),
#  ('expressvpncom', 869),
#  ('goldmines', 868),
#  ('contingencymedicalcom', 856),
#  ('poso', 785),
#  ('800941sean', 740),
#  ('there′s', 728),
#  ('goodrancherscom', 710),
#  ('timcastcom', 685),
#  ('moinkboxcom', 682),
#  ('levinpodcast', 668),
#  ('goldcocom', 666),
#  ('he′s', 651),
#  ('patriotmobilecom', 614),
#  ('8009062440', 592),
#  ('mypillowcom', 582),
#  ('warroomhealthcom', 560),
#  ('americanfinancingnet', 554),
#  ('goldline', 521),
#  ('hillsdalecom', 513),
#  ('can′t', 503),
#  ('inventhelp', 497),
#  ('relieffactorcom', 451),
#  ('lifelockcom', 442),
#  ('blindscom', 442),
#  ('unpluggedcom', 394),
#  ('nmls', 391),
#  ('8006301492', 389),
#  ('transhumanism', 380),
#  ('doesn′t', 378),
#  ('didn′t', 371),
#  ('coromina', 369),
#  ('1800lifelock', 358),
#  ('glowfm', 354),
#  ('♪', 343),
#  ('i′ve', 342),
#  ('what′s', 325),
#  ('choqcom', 320),
#  ('let′s', 319),
#  ('blazetvcom', 307),
#  ('policygeniuscom', 303),
#  ('we′ve', 302),
#  ('posobiec', 302),
#  ('mailbag', 300),
#  ('972patriot', 292),
#  ('healthcom', 292),
#  ('800941shawn', 289),
#  ('182334', 287),
#  ('mondaycom', 273),
#  ('katonji', 272),
#  ('phx', 270),
#  ('luckyland', 265),
#  ('rwjbarnabas', 262),
#  ('realestateagentsitrustcom', 257),
#  ('chalkcom', 254),
#  ('inventhelpcom', 254),
#  ('grassfed', 253),
#  ('ractopamine', 247),
#  ('levinn', 247),
#  ('allform', 242),
#  ('transing', 242),
#  ('abnormal50', 241),
#  ('helixsleepcom', 239),
#  ('selfpaced', 237),
#  ('michaelsavagecom', 236),
#  ('here′s', 231),
#  ('tuttletwinsbeckcom', 226),
#  ('8667213300', 224),
#  ('puretalk', 223),
#  ('chumbacasinocom', 222),
#  ('we′ll', 221),
#  ('rubinreportlocalscom', 221),
#  ('roughgreenscom', 221),
#  ('blazetv', 215),
#  ('goldco', 213),
#  ('grassfinished', 212),
#  ('nonwithdrawable', 212),
#  ('1800gambler', 212),
#  ('888727beck', 210),
#  ('betmgmcom', 210),
#  ('gamesense', 207),
#  ('lockcom', 203),
#  ('dailywirepluscom', 203),
#  ('carshieldcom', 203),
#  ('gcuedu', 202),
#  ('preparewithbannoncom', 198),
#  ('liveinforhillsdalecom', 191),
#  ('tvcom', 190),
#  ('choq', 189),
#  ('sportsbooks', 189),
#  ('tpusacom', 185),
#  ('oreillycom', 181),
#  ('she′s', 177),
#  ('epicwillcom', 177),
#  ('swissamericacom', 176),
#  ('32494', 176),
#  ('factormealscom', 176),
#  ('you′ve', 175),
#  ('i′ll', 171),
#  ('they′ve', 171),
#  ('♪♪♪', 170),
#  ('jbp', 170),
#  ('itarget', 169),
#  ('goldlinecom', 168),
#  ('lopin', 162),
#  ('itargetprocom', 160),
#  ('mobilecom', 158),
#  ('8003918888', 155),
#  ('storemidastouchcom', 154),
#  ('getupside', 151),
#  ('meidas', 150),
#  ('yaku', 149),
#  ('bonjino', 148),
#  ('genucelcom', 143),
#  ('8004relief', 141),
#  ('policygenius', 139),
#  ('preparewithglenncom', 138),
#  ('bonginocom', 137),
#  ('866goldline', 137),
#  ('phxonhannitycom', 137),
#  ('rwjbhorg', 136),
#  ('startmailcom', 135),
#  ('isn′t', 134),
#  ('i†m', 134),
#  ('luckylandslotscom', 134),
#  ('jbp50', 134),
#  ('zstack', 131),
#  ('taxsheltered', 131),
#  ('sat123com', 130),
#  ('dace', 128),
#  ('vidovsky', 128),
#  ('genucellcom', 127),
#  ('patreoncom', 127),
#  ('elysiumhealthcom', 127),
#  ('zstacklifecom', 126),
#  ('ipvanish', 126),
#  ('genucel', 125),
#  ('betterhelpcom', 125),
#  ('bodycom', 123),
#  ('sitewide', 123),
#  ('you′ll', 122),
#  ('theblazecom', 122),
#  ('putinoids', 122),
#  ('greenscom', 122),
#  ('¬and', 122),
#  ('wouldn′t', 120),
#  ('kovat', 119),
#  ('startmail', 119),
#  ('genucell', 119),
#  ('zelenko', 118),
#  ('talkcom', 116),
#  ('zirkle', 115),
#  ('latipo', 114),
#  ('they′ll', 111),
#  ('won′t', 111),
#  ('preborncom', 111),
#  ('sweatblockcom', 110),
#  ('1102011', 110),
#  ('8009663117', 109),
#  ('18004relief', 108),
#  ('allformcom', 107),
#  ('wasn′t', 104),
#  ('financingnet', 104),
#  ('gcu', 104),
#  ('instacartcom', 104),
#  ('moinkbox', 103),
#  ('who′s', 102),
#  ('nondiscrete', 102),
#  ('puretalkusacom', 100),
#  ('hurwitz', 99),
#  ('rodenstock', 99),
#  ('beckcom', 99),
#  ('peepee', 98),
#  ('glenbeckcom', 98),
#  ('ihearttaxrefundscom', 95),
#  ('altoiracom', 95),
#  ('833gold777', 95),
#  ('beardvet', 94),
#  ('haven′t', 92),
#  ('patriotacademycom', 91),
#  ('halfounce', 91)]

# %%
unique_unigrams['tv']
# Out:
# [('xe2x80x94', 363567),
#  ('xe2x99xaa', 355856),
#  ('xe2x80x94xe2x80x94', 41798),
#  ('xe2x99xaaxe2x99xaa', 24526),
#  ('xefxbfxbd', 23754),
#  ('borisjohnson', 22464),
#  ('trelegy', 19258),
#  ('rinvoq', 19033),
#  ('safelite', 18377),
#  ('ofxe2x80x94', 18220),
#  ('ozempicxc2xae', 17069),
#  ('rybelsusxc2xae', 14820),
#  ('oncedaily', 10967),
#  ('otezla', 9732),
#  ('skyrizi', 9158),
#  ('0ur', 8398),
#  ('0k', 8246),
#  ('boostxc2xae', 8131),
#  ('toxe2x80x94', 8110),
#  ('botoxxc2xae', 8052),
#  ('limu', 7873),
#  ('tremfyaxc2xae', 7714),
#  ('southxe2x80x94east', 7663),
#  ('isxe2x80x94', 7562),
#  ('itxefxbfxbds', 7405),
#  ('forxe2x80x94', 6810),
#  ('cabenuva', 6782),
#  ('ixe2x80x94', 6500),
#  ('itxe2x80x94', 6422),
#  ('astepro', 6333),
#  ('dupixent', 6309),
#  ('northxe2x80x94west', 6230),
#  ('relaxium', 6140),
#  ('neuriva', 5995),
#  ('southxe2x80x94west', 5919),
#  ('latuda', 5658),
#  ('jardiance', 5630),
#  ('psoriatic', 5595),
#  ('thatxe2x80x94', 5505),
#  ('prevagen', 5404),
#  ('indeedcomhire', 5181),
#  ('ahah', 5006),
#  ('shingrix', 4964),
#  ('leqvio', 4910),
#  ('ubrelvy', 4900),
#  ('squawks', 4821),
#  ('inxe2x80x94', 4641),
#  ('emu', 4630),
#  ('biktarvy', 4600),
#  ('ingrezza', 4539),
#  ('sulfonylurea', 4419),
#  ('thundery', 4380),
#  ('metres', 4011),
#  ('thinkxe2x80x94', 3949),
#  ('arthel', 3947),
#  ('kisqali', 3917),
#  ('longxe2x80x94term', 3842),
#  ('nucala', 3768),
#  ('neoplasia', 3744),
#  ('bbcxefxbfxbds', 3727),
#  ('cibinqo', 3686),
#  ('theyxe2x80x94', 3580),
#  ('tremfyantxc2xae', 3558),
#  ('fasenra', 3402),
#  ('stelaraxc2xae', 3396),
#  ('willxe2x80x94', 3386),
#  ('quliptaxe2x84xa2', 3362),
#  ('brittney', 3295),
#  ('caplyta', 3291),
#  ('southwards', 3263),
#  ('xiidra', 3240),
#  ('coventry', 3099),
#  ('soxe2x80x94called', 3093),
#  ('northxe2x80x94east', 3047),
#  ('thisxe2x80x94', 3042),
#  ('flonase', 3017),
#  ('covidxe2x80x9419', 2982),
#  ('breztri', 2976),
#  ('enbrel', 2961),
#  ('wooo', 2867),
#  ('apologise', 2854),
#  ('mavyret', 2821),
#  ('xe2x99xaaliberty', 2788),
#  ('fingersticks', 2753),
#  ('biotrue', 2646),
#  ('qunol', 2620),
#  ('cosentyx', 2618),
#  ('vyvgart', 2611),
#  ('vuityxe2x84xa2', 2610),
#  ('anncr', 2604),
#  ('entresto', 2592),
#  ('ketoacidosis', 2586),
#  ('tezspirexe2x84xa2', 2555),
#  ('jacqui', 2544),
#  ('000000000', 2543),
#  ('xe2x99xaaand', 2521),
#  ('nunormal', 2514),
#  ('apologised', 2492),
#  ('0h', 2472),
#  ('noxe2x80x94one', 2459),
#  ('ifxe2x80x94', 2443),
#  ('0ne', 2417),
#  ('farxiga', 2414),
#  ('allxe2x80x94', 2412),
#  ('donxefxbfxbdt', 2408),
#  ('neutrogenaxc2xae', 2341),
#  ('dup', 2318),
#  ('onceweekly', 2291),
#  ('lensky', 2268),
#  ('angi', 2242),
#  ('levelling', 2239),
#  ('thatxefxbfxbds', 2232),
#  ('ixefxbfxbdm', 2217),
#  ('coolsculpting', 2212),
#  ('opdivo', 2176),
#  ('yervoy', 2167),
#  ('kaitlan', 2150),
#  ('ganske', 2143),
#  ('libertyxe2x99xaa', 2116),
#  ('mrjohnson', 2115),
#  ('upwork', 2090),
#  ('moderatetosevere', 2083),
#  ('aboutxe2x80x94', 2081),
#  ('voya', 2067),
#  ('cologuard', 2061),
#  ('onxe2x80x94', 2060),
#  ('withah', 2034),
#  ('notxe2x80x94', 2007),
#  ('miracleear', 2005),
#  ('eosinophilic', 1999),
#  ('hardtalk', 1995),
#  ('showery', 1987),
#  ('rmt', 1966),
#  ('nic', 1957),
#  ('bookingcom', 1941),
#  ('aleve', 1934),
#  ('withwith', 1929),
#  ('veryxe2x80x94', 1917),
#  ('xe2x80x9cfind', 1909),
#  ('itxe2x80x99s', 1897),
#  ('vardy', 1889),
#  ('nowxe2x80x94', 1875),
#  ('trizone', 1874),
#  ('xefxacx81nd', 1874),
#  ('glucerna', 1861),
#  ('themselfxe2x80x9d', 1831),
#  ('roubles', 1818),
#  ('verzenio', 1802),
#  ('thinkorswimxc2xae', 1784),
#  ('kardia', 1766),
#  ('linzess', 1760),
#  ('upworkcom', 1752),
#  ('xe2x99xaaive', 1749),
#  ('eole', 1730),
#  ('nexium', 1723),
#  ('ourxe2x80x94', 1722),
#  ('uxe2x80x94turn', 1713),
#  ('preservision', 1711),
#  ('rosland', 1700),
#  ('weathertech', 1699),
#  ('1000000000', 1691),
#  ('theirxe2x80x94', 1688),
#  ('pronamel', 1686),
#  ('cyp3a4', 1678),
#  ('reallyxe2x80x94', 1671),
#  ('xfi', 1664),
#  ('driftin', 1662),
#  ('orxe2x80x94', 1658),
#  ('colours', 1650),
#  ('flyin', 1648),
#  ('alisyn', 1638),
#  ('wasxe2x80x94', 1637),
#  ('azovstal', 1635),
#  ('xe2x99xaai', 1626),
#  ('gove', 1622),
#  ('vraylar', 1620),
#  ('simparica', 1612),
#  ('securityedgexe2x84xa2', 1578),
#  ('sfx', 1565),
#  ('isobars', 1562),
#  ('cfpxc2xae', 1558),
#  ('northerly', 1552),
#  ('asxe2x80x94', 1551),
#  ('wearily', 1539),
#  ('tonnes', 1516),
#  ('tepezza', 1512),
#  ('fulvestrant', 1509),
#  ('letxefxbfxbds', 1489),
#  ('costxe2x80x94ofxe2x80x94living', 1489),
#  ('travellers', 1486),
#  ('itxe2x80x9d', 1484),
#  ('doxe2x80x94', 1484),
#  ('coventrydirectcom', 1471),
#  ('suella', 1457),
#  ('tum', 1457),
#  ('ringback', 1441),
#  ('soxe2x80x94', 1434),
#  ('yourxe2x80x94', 1431),
#  ('borisjohnsons', 1422),
#  ('braverman', 1413)]

# %%
total_bigram_frequencies = {}
for source_bigrams in [email_bigrams, podcast_bigrams, tv_bigrams]:
    for bigram, freq in source_bigrams.items():
        total_bigram_frequencies[bigram] = total_bigram_frequencies.get(bigram, 0) + freq

relative_bigram_frequencies = {}
for source, source_bigrams in [("emails", email_bigrams), ("podcasts", podcast_bigrams), ("tv", tv_bigrams)]:
    relative_bigram_frequencies[source] = {bigram: freq / total_bigram_frequencies[bigram] for bigram, freq in source_bigrams.items()}

unique_bigrams = {}
for source, source_relative_frequencies in relative_bigram_frequencies.items():
    keys = sorted(source_relative_frequencies.keys(), key=lambda x: source_relative_frequencies[x], reverse=True)[:200]
    unique_bigrams[source] = [(key, total_bigram_frequencies[key]) for key in keys]

# %%
unique_bigrams['emails']
# Out:
# [(('͏', '͏'), 250200),
#  (('to', 'dpwillis67gmailcom'), 16697),
#  (('can', '’'), 15731),
#  (('actblue', 'express'), 8909),
#  (('please', 'unsubscribe'), 7884),
#  (('͏', '͏͏'), 7747),
#  (('͏͏', '͏'), 7712),
#  (('fewer', 'emails'), 7457),
#  (('receive', 'email'), 7168),
#  (('now', '»'), 6451),
#  (('receive', 'fewer'), 5334),
#  (('sent', 'todpwillis67gmailcom'), 5289),
#  (('unsubscribe', 'here'), 5236),
#  (('alexandria', 'va'), 4123),
#  (('va', '22314'), 4055),
#  (('not', 'deductible'), 4028),
#  (('contribution', 'account'), 4021),
#  (('fundraising', 'deadline'), 3973),
#  (('183', 'alexandria'), 3830),
#  (('dpwillis67gmailcom', 'to'), 3829),
#  (('street', '183'), 3714),
#  (('»', 'donate'), 3613),
#  (('isn', '’'), 3347),
#  (('america', 'jfc'), 3305),
#  (('other', 'amount'), 3235),
#  (('change', 'yoursubscription'), 3231),
#  (('doesn', '’'), 2897),
#  (('dpwillis67gmailcom', 'should'), 2874),
#  (('unsubscribe', 'for'), 2855),
#  (('subscribed', 'or'), 2785),
#  (('yoursubscription', 'information'), 2785),
#  (('unsubscribe', 'paid'), 2771),
#  (('preferences', 'unsubscribe'), 2766),
#  (('dc', '20003'), 2634),
#  (('dpwillis67gmailcom', 'email'), 2614),
#  (('donate', 'paid'), 2591),
#  (('copyright', '©'), 2496),
#  (('pleaseclick', 'here'), 2486),
#  (('via', 'actionnetworkorg'), 2461),
#  (('actionnetworkorg', 'to'), 2461),
#  (('name', 'oraddress'), 2461),
#  (('oraddress', 'or'), 2461),
#  (('©', '2022'), 2434),
#  (('majority', 'pacs'), 2413),
#  (('tounsubscribe', 'from'), 2360),
#  (('governor', 'po'), 2331),
#  (('senate', 'po'), 2314),
#  (('dpwillis67gmailcom', 'if'), 2305),
#  (('inc', 'po'), 2293),
#  (('★', '★'), 2263),
#  (('if', 'dpwillis67gmailcom'), 2254),
#  (('again', 'pac'), 2249),
#  (('what', '’'), 2247),
#  (('orcandidates', 'committee'), 2221),
#  (('unsubscribe', 'peter'), 2206),
#  (('»', 'contribute'), 2198),
#  (('noncontribution', 'account'), 2128),
#  (('income', 'taxpurposes'), 2103),
#  (('donation', '»'), 2087),
#  (('dpwillis67gmailcom', 'dont'), 2061),
#  (('couldn', '’'), 2059),
#  (('pacs', 'noncontribution'), 2048),
#  (('contribute', '5'), 2031),
#  (('pacs', 'contribution'), 2025),
#  (('nw', 'suite'), 2011),
#  (('house', 'majoritypac'), 2009),
#  (('50', 'contribute'), 2000),
#  (('here', 'unsubscribe'), 1984),
#  (('from', 'usplease'), 1948),
#  (('50', 'donate'), 1930),
#  (('the', 'ndrc'), 1927),
#  (('street', 'nw'), 1908),
#  (('25', 'contribute'), 1904),
#  (('or', 'candidatescommittee'), 1884),
#  (('700', '13th'), 1860),
#  (('deductible', 'as'), 1845),
#  (('housemajority', 'pacs'), 1841),
#  (('50', '»'), 1813),
#  (('your', 'donationwill'), 1773),
#  (('immediately', 'donate'), 1761),
#  (('trump', 'gold'), 1752),
#  (('100', 'donate'), 1739),
#  (('donate', '»'), 1729),
#  (('stored', 'your'), 1719),
#  (('pelosi', '’'), 1715),
#  (('emails', 'anymoreunsubscribe'), 1711),
#  (('usplease', 'unsubscribe'), 1685),
#  (('100', '»'), 1683),
#  (('25', '»'), 1669),
#  (('contribution', 'today'), 1668),
#  (('jfc', 'a'), 1667),
#  (('emails', 'please'), 1645),
#  (('forwarded', 'message'), 1631),
#  (('paymentinformation', 'with'), 1626),
#  (('immediately', 'contribute'), 1626),
#  (('dc', '20005'), 1617),
#  (('not', 'taxdeductible'), 1607),
#  (('endofmonth', 'deadline'), 1597),
#  (('»', '50'), 1588),
#  (('20005', 'united'), 1584),
#  (('25', 'donate'), 1582),
#  (('express', 'donate'), 1567),
#  (('custom', 'donation'), 1563),
#  (('todpwillis67gmailcom', 'to'), 1562),
#  (('forcongress', 'po'), 1530),
#  (('contribute', '250'), 1522),
#  (('haven', '’'), 1514),
#  (('page625', 'first'), 1489),
#  (('to', '88022'), 1483),
#  (('va', '22219'), 1477),
#  (('ourdemocratic', 'majority'), 1471),
#  (('contribute', 'today'), 1470),
#  (('here', 'tounsubscribe'), 1459),
#  (('»', '100'), 1450),
#  (('»', '25'), 1447),
#  (('5', '»'), 1434),
#  (('a', '“'), 1425),
#  (('like', 'tounsubscribe'), 1416),
#  (('donate', 'monthly'), 1415),
#  (('orlando', 'fl'), 1404),
#  (('7', '»'), 1397),
#  (('our', 'endofmonth'), 1390),
#  (('grassrootssupporters', 'like'), 1375),
#  (('aren', '’'), 1363),
#  (('senate', 'inc'), 1361),
#  (('fl', '32853'), 1359),
#  (('inc', 'dont'), 1356),
#  (('88022', 'to'), 1356),
#  (('clickhere', 'to'), 1350),
#  (('us', 'pleaseunsubscribe'), 1347),
#  (('32853', 'united'), 1344),
#  (('→', 'paid'), 1343),
#  (('donationwill', 'go'), 1342),
#  (('m', 'counting'), 1332),
#  (('contribute', 'monthly'), 1316),
#  (('800', 'washington'), 1306),
#  (('gop', '’'), 1300),
#  (('now', '→'), 1298),
#  (('100', 'contribute'), 1298),
#  (('candidate', '’'), 1294),
#  (('youreceived', 'this'), 1278),
#  (('suite', '800'), 1278),
#  (('unsubscribe', 'message'), 1274),
#  (('believe', 'youreceived'), 1272),
#  (('youcan', 'unsubscribe'), 1271),
#  (('2nd', 'ave'), 1258),
#  (('taxdeductible', 'paid'), 1257),
#  (('democrats', '’'), 1257),
#  (('ave', 's'), 1255),
#  (('o', 'box536926'), 1255),
#  (('box536926', 'orlando'), 1255),
#  (('401', '2nd'), 1254),
#  (('on', 'grassrootssupporters'), 1253),
#  (('this', 'preferencespage625'), 1248),
#  (('preferencespage625', 'first'), 1248),
#  (('»', 'thank'), 1245),
#  (('not', 'implyendorsement'), 1242),
#  (('seattle', 'wa'), 1239),
#  (('unsubscribe', 'friend'), 1223),
#  (('street', 'se'), 1223),
#  (('request', 'fewer'), 1221),
#  (('re', 'counting'), 1221),
#  (('raleigh', 'nc'), 1218),
#  (('url', 'below'), 1214),
#  (('emails', 'altogether'), 1209),
#  (('320', 'first'), 1208),
#  (('10', 'donate'), 1204),
#  (('3', '»'), 1204),
#  (('fec', 'deadline'), 1201),
#  (('wouldn', '’'), 1196),
#  (('wa', '98104'), 1192),
#  (('longer', 'receiveemail'), 1180),
#  (('receiveemail', 'from'), 1180),
#  (('donation', 'willgo'), 1178),
#  (('herschel', 'inc'), 1178),
#  (('contribute', '3'), 1163),
#  (('ave', 'se'), 1152),
#  (('endofmonth', 'goal'), 1148),
#  (('click', 'hereto'), 1144),
#  (('this', 'emailwas'), 1137),
#  (('emailwas', 'sent'), 1136),
#  (('defeat', 'chuck'), 1133),
#  (('»', '»'), 1132),
#  (('2022', 'paid'), 1131),
#  (('account', '”'), 1131),
#  (('»', 'or'), 1129),
#  (('endofquarter', 'deadline'), 1125),
#  (('ifyouve', 'saved'), 1124),
#  (('email', 'wassent'), 1120),
#  (('taxpurposes', 'paid'), 1118),
#  (('inerror', 'or'), 1112),
#  (('left', '’'), 1108),
#  (('98104', 'click'), 1103),
#  (('to', 'removeyourself'), 1096),
#  (('removeyourself', 'from'), 1096),
#  (('this', 'preferences'), 1092),
#  (('received', 'thismessage'), 1091),
#  (('preferences', 'page625'), 1091),
#  (('amount', '»'), 1080),
#  (('housemajority', 'pac'), 1080)]

# %%
unique_bigrams['podcasts']
# Out:
# [(('beck', 'program'), 3286),
#  (('mr', 'producer'), 1752),
#  (('to', 'puretalkcom'), 1574),
#  (('levin', 'podcast'), 1392),
#  (('birch', 'gold'), 1384),
#  (('enter', 'promo'), 1341),
#  (('§§', '§§'), 1302),
#  (('beautiful', 'anonymous'), 1282),
#  (('oreilly', 'update'), 1268),
#  (('to', '65532'), 1220),
#  (('free', 'silver'), 1218),
#  (('michael', 'savage'), 1176),
#  (('the', 'oreilly'), 1101),
#  (('877444gold', 'or'), 1092),
#  (('text', 'gold'), 1042),
#  (('rough', 'greens'), 1030),
#  (('good', 'ranchers'), 1008),
#  (('spin', 'news'), 994),
#  (('code', 'sean'), 981),
#  (('events', 'daily'), 928),
#  (('slash', 'sean'), 925),
#  (('knowles', 'show'), 922),
#  (('to', '989898'), 916),
#  (('slash', 'hannity'), 890),
#  (('anonymous', 'every'), 847),
#  (('bonus', 'bets'), 842),
#  (('lock', 'dot'), 838),
#  (('talk', 'text'), 817),
#  (('contingency', 'medical'), 816),
#  (('room', 'pandemic'), 786),
#  (('i', 'don′t'), 777),
#  (('thats', 'levin'), 775),
#  (('slash', 'beck'), 768),
#  (('slash', 'ben'), 763),
#  (('tuttle', 'twins'), 744),
#  (('timcast', 'irl'), 724),
#  (('savage', 'premium'), 705),
#  (('american', 'homeowners'), 702),
#  (('expressvpncom', 'slash'), 693),
#  (('room', 'health'), 693),
#  (('slash', 'levin'), 688),
#  (('american', 'hartford'), 678),
#  (('hartford', 'gold'), 678),
#  (('savage', 'nation'), 669),
#  (('text', 'bannon'), 669),
#  (('code', 'levinpodcast'), 666),
#  (('code', 'levin'), 647),
#  (('vitality', 'stack'), 642),
#  (('post', 'deep'), 629),
#  (('save', '67'), 627),
#  (('goldcocom', 'slash'), 618),
#  (('code', 'beck'), 614),
#  (('dailywirecom', 'slash'), 610),
#  (('65532', 'again'), 604),
#  (('slash', 'glenn'), 600),
#  (('silver', 'delivered'), 599),
#  (('chumba', 'casino'), 595),
#  (('code', 'shapiro'), 590),
#  (('the', 'megyn'), 586),
#  (('mug', 'club'), 585),
#  (('moinkboxcom', 'slash'), 579),
#  (('puretalkcom', 'promo'), 579),
#  (('public', 'sq'), 564),
#  (('matt', 'wall'), 557),
#  (('puts', 'veteran'), 550),
#  (('oreilly', 'sent'), 547),
#  (('only', 'precious'), 545),
#  (('again', '877444gold'), 544),
#  (('world', 'target'), 544),
#  (('home', 'stolen'), 543),
#  (('call', '877444gold'), 539),
#  (('877444gold', '877444gold'), 532),
#  (('touch', 'podcast'), 528),
#  (('metal', 'dealer'), 527),
#  (('silver', 'since'), 524),
#  (('401k', 'tell'), 520),
#  (('knowles', 'this'), 519),
#  (('for', 'hillsdalecom'), 511),
#  (('seconds', 'station'), 510),
#  (('hometitlelockcom', 'slash'), 507),
#  (('hillsdale', 'dot'), 505),
#  (('patriot', 'supply'), 503),
#  (('patriotmobilecom', 'slash'), 501),
#  (('youtubecom', 'slash'), 500),
#  (('segments', 'coming'), 499),
#  (('now', 'meets'), 496),
#  (('company', 'fedex'), 492),
#  (('fedex', 'where'), 492),
#  (('apply', 'see'), 492),
#  (('by', 'transcribed'), 478),
#  (('health', 'dot'), 471),
#  (('8773813811', '8773813811'), 470),
#  (('quinton', 'here'), 466),
#  (('com', 'promo'), 458),
#  (('educated', 'american'), 454),
#  (('female', 'vitality'), 451),
#  (('serious', 'prizes'), 451),
#  (('redeem', 'some'), 450),
#  (('the', 'chumba'), 450),
#  (('chumba', 'life'), 450),
#  (('casino', 'always'), 446),
#  (('slash', 'bannon'), 445),
#  (('leftovers', 'or'), 444),
#  (('subscribe', 'today'), 442),
#  (('demon', 'hide'), 438),
#  (('gavin', 'mcinnes'), 437),
#  (('ziprecruitercom', 'slash'), 436),
#  (('stitcher', 'apple'), 435),
#  (('to', 'levinforhillsdalecom'), 435),
#  (('plus', 'terms'), 435),
#  (('to', 'dailywirecom'), 430),
#  (('number', '8773813811'), 430),
#  (('wire', 'production'), 429),
#  (('neutral', 'operations'), 428),
#  (('male', 'vitality'), 428),
#  (('laughing', 'laughing'), 427),
#  (('puretalkcom', 'enter'), 425),
#  (('daughters', 'cancer'), 423),
#  (('above', 'ive'), 420),
#  (('code', 'tim'), 420),
#  (('at', 'goodrancherscom'), 420),
#  (('mobile', 'dot'), 418),
#  (('host', 'beautiful'), 418),
#  (('gets', 'heartbreaking'), 418),
#  (('copyright', 'daily'), 418),
#  (('code', 'jersey'), 418),
#  (('don′t', 'know'), 416),
#  (('code', 'bongino'), 416),
#  (('pandora', 'stitcher'), 415),
#  (('wire', '2022'), 415),
#  (('dmv', 'or'), 413),
#  (('stitcher', 'or'), 412),
#  (('production', 'copyright'), 408),
#  (('slash', 'midas'), 408),
#  (('daily', 'cancellation'), 407),
#  (('with', 'betmgm'), 403),
#  (('it′s', 'not'), 400),
#  (('from', 'birch'), 395),
#  (('covid', 'fascism'), 394),
#  (('mathis', 'glover'), 394),
#  (('972', 'patriot'), 392),
#  (('the', 'tuttle'), 390),
#  (('slash', 'bongino'), 388),
#  (('goodrancherscom', 'subscribe'), 386),
#  (('wire', 'plus'), 385),
#  (('producer', 'jeremy'), 385),
#  (('slash', 'knowles'), 378),
#  (('slash', 'timcast'), 372),
#  (('jersey', 'arts'), 371),
#  (('free', 'activation'), 370),
#  (('mike', 'coromina'), 369),
#  (('yourself', 'verify'), 367),
#  (('or', 'chumba'), 362),
#  (('simply', 'considered'), 347),
#  (('smith', 'anderson'), 347),
#  (('cooper', 'jason'), 347),
#  (('comedy', 'ill'), 346),
#  (('sweat', 'block'), 345),
#  (('savage', 'podcast'), 342),
#  (('mantis', 'x'), 342),
#  (('chris', 'gethard'), 341),
#  (('morning', 'wire'), 340),
#  (('gethard', 'and'), 339),
#  (('making', 'earth'), 336),
#  (('upgrade', 'comedy'), 336),
#  (('coogler', 'stephen'), 336),
#  (('it′s', 'a'), 334),
#  (('priority', 'fedex'), 334),
#  (('uses', 'fedex'), 333),
#  (('xm', 'pandora'), 333),
#  (('at', 'moinkboxcom'), 331),
#  (('his', 'recycled'), 329),
#  (('recycled', 'bamboo'), 329),
#  (('influencer', 'tweeted'), 327),
#  (('bamboo', 'tshirts'), 326),
#  (('quinton', 'unexpectedly'), 326),
#  (('name', 'hometitlelockcom'), 326),
#  (('5g', 'samsung'), 326),
#  (('athletic', 'greens'), 325),
#  (('989898', 'and'), 324),
#  (('businesses', 'receive'), 324),
#  (('strong', 'heart'), 324),
#  (('tshirts', 'quinton'), 322),
#  (('disease', 'sneaks'), 322),
#  (('alaskan', 'salmon'), 321),
#  (('lions', 'heart'), 320),
#  (('pressure', 'bad'), 319),
#  (('cholesterol', 'diabetes'), 319),
#  (('free', 'courses'), 318),
#  (('disease', 'builds'), 318),
#  (('time', 'hypertension'), 318),
#  (('code', 'poso'), 317),
#  (('free', 'hillsdale'), 316),
#  (('2040', 'impressive'), 315),
#  (('soft', 'gel'), 315),
#  (('gel', 'supplement'), 314),
#  (('gold', 'group'), 313),
#  (('in', 'antioxidants'), 313),
#  (('slash', 'subscribe'), 312),
#  (('supplement', 'rich'), 312)]

# %%
unique_bigrams['tv']
# Out:
# [(('xe2x99xaa', 'xe2x99xaa'), 124106),
#  (('xe2x80x94', 'the'), 18736),
#  (('xe2x80x94', 'and'), 15905),
#  (('comcast', 'business'), 15730),
#  (('the', 'xe2x80x94'), 11553),
#  (('sleep', 'number'), 9787),
#  (('xe2x99xaa', 'ive'), 9763),
#  (('weather', 'front'), 9658),
#  (('xe2x99xaa', 'i'), 9217),
#  (('clearer', 'skin'), 8069),
#  (('man', 'xe2x99xaa'), 7761),
#  (('smart', 'bed'), 7674),
#  (('how', 'abbvie'), 7551),
#  (('xe2x80x94', 'a'), 7284),
#  (('number', '360'), 7046),
#  (('the', 'programme'), 7000),
#  (('boostxc2xae', 'high'), 6988),
#  (('to', 'xe2x80x94'), 6987),
#  (('and', 'xe2x80x94'), 6888),
#  (('occur', 'tell'), 6883),
#  (('need', 'xe2x99xaa'), 6776),
#  (('xe2x80x94', 'that'), 6521),
#  (('995', 'a'), 6298),
#  (('a', 'xe2x80x94'), 6232),
#  (('xe2x99xaa', 'liberty'), 6117),
#  (('sunny', 'spells'), 6094),
#  (('if', 'allergic'), 6084),
#  (('xe2x80x94', 'but'), 6078),
#  (('fisher', 'investments'), 6022),
#  (('some', 'rain'), 5995),
#  (('provider', 'about'), 5910),
#  (('xe2x80x94', 'to'), 5794),
#  (('xfinity', 'mobile'), 5733),
#  (('barnes', 'firm'), 5632),
#  (('more', 'cloud'), 5509),
#  (('the', 'southxe2x80x94east'), 5507),
#  (('mm', 'hm'), 5497),
#  (('psoriatic', 'arthritis'), 5371),
#  (('1st', 'time'), 5352),
#  (('xe2x99xaa', 'safelite'), 5312),
#  (('singers', 'xe2x99xaa'), 5302),
#  (('safelite', 'replace'), 5284),
#  (('xe2x99xaa', 'its'), 5278),
#  (('safelite', 'repair'), 5240),
#  (('repair', 'safelite'), 5206),
#  (('xe2x99xaa', 'and'), 5161),
#  (('xe2x99xaa', 'you'), 5071),
#  (('delivers', 'quality'), 5047),
#  (('instantly', 'delivers'), 5027),
#  (('visit', 'indeedcomhire'), 4992),
#  (('reactions', 'can'), 4889),
#  (('with', 'rybelsusxc2xae'), 4854),
#  (('candidates', 'matching'), 4770),
#  (('max', 'protein'), 4673),
#  (('abbvie', 'could'), 4666),
#  (('xe2x80x94', 'in'), 4591),
#  (('with', 'merrill'), 4565),
#  (('sudden', 'breathing'), 4549),
#  (('few', 'showers'), 4534),
#  (('xe2x99xaa', 'the'), 4519),
#  (('in', 'ensure'), 4516),
#  (('colonial', 'penn'), 4508),
#  (('xe2x80x94', 'it'), 4470),
#  (('liberty', 'xe2x99xaa'), 4431),
#  (('business', 'powering'), 4415),
#  (('sulfonylurea', 'or'), 4413),
#  (('across', 'scotland'), 4312),
#  (('mutual', 'customizes'), 4277),
#  (('some', 'showers'), 4221),
#  (('is', 'xe2x80x94'), 4220),
#  (('90', 'clearer'), 4214),
#  (('360', 'smart'), 4196),
#  (('business', 'internet'), 4159),
#  (('plaque', 'psoriasis'), 4140),
#  (('it', 'xe2x80x94'), 4125),
#  (('my', 'a1c'), 4116),
#  (('that', 'xe2x80x94'), 4113),
#  (('xe2x80x94', 'is'), 4108),
#  (('you', 'xe2x80x94'), 4106),
#  (('xe2x99xaa', 'we'), 4078),
#  (('with', 'rinvoq'), 4017),
#  (('music', 'xe2x99xaa'), 4009),
#  (('xe2x80x94', 'i'), 3993),
#  (('with', 'ah'), 3988),
#  (('xe2x99xaa', 'xe2x99xaaxe2x99xaa'), 3976),
#  (('a', 'sulfonylurea'), 3963),
#  (('xe2x80x94', 'as'), 3952),
#  (('a', 'oncedaily'), 3940),
#  (('oncedaily', 'pill'), 3936),
#  (('or', 'worsening'), 3869),
#  (('robot', 'must'), 3841),
#  (('worsen', 'kidney'), 3744),
#  (('with', 'trelegy'), 3730),
#  (('prop', '27'), 3729),
#  (('endocrine', 'neoplasia'), 3728),
#  (('neoplasia', 'syndrome'), 3727),
#  (('multiple', 'endocrine'), 3700),
#  (('to', 'dehydration'), 3700),
#  (('xe2x99xaaxe2x99xaa', 'xe2x99xaa'), 3687),
#  (('xe2x80x94', 'this'), 3680),
#  (('western', 'scotland'), 3671),
#  (('xe2x99xaa', 'oh'), 3664),
#  (('neck', 'severe'), 3658),
#  (('sugar', 'risk'), 3637),
#  (('relaxium', 'sleep'), 3634),
#  (('xe2x80x94', 'you'), 3628),
#  (('we', 'xe2x80x94'), 3601),
#  (('fight', 'infections'), 3593),
#  (('the', 'bbcxefxbfxbds'), 3573),
#  (('include', 'pancreatitis'), 3572),
#  (('replace', 'xe2x99xaa'), 3571),
#  (('the', 'southxe2x80x94west'), 3542),
#  (('xe2x80x94', 'we'), 3532),
#  (('its', 'ingredients'), 3500),
#  (('emerge', 'tremfyantxc2xae'), 3417),
#  (('xe2x99xaa', 'this'), 3413),
#  (('specialist', 'about'), 3406),
#  (('the', 'northxe2x80x94west'), 3404),
#  (('today', 'comcast'), 3368),
#  (('xe2x80x94', 'with'), 3361),
#  (('neuriva', 'plus'), 3352),
#  (('from', 'xfinity'), 3313),
#  (('in', 'xe2x80x94'), 3311),
#  (('and', 'tiredness'), 3303),
#  (('weather', 'fronts'), 3286),
#  (('your', 'a1c'), 3283),
#  (('had', 'medullary'), 3241),
#  (('eye', 'pain'), 3239),
#  (('dehydration', 'which'), 3237),
#  (('business', 'mobile'), 3226),
#  (('diarrhea', 'may'), 3224),
#  (('youre', 'age'), 3176),
#  (('serious', 'infections'), 3170),
#  (('disease', 'risk'), 3149),
#  (('try', 'boostxc2xae'), 3145),
#  (('xe2x80x94', 'of'), 3120),
#  (('key', 'nutrients'), 3092),
#  (('migraine', 'attacks'), 3091),
#  (('thirty', 'grams'), 3078),
#  (('infections', 'including'), 3075),
#  (('dramatic', 'development'), 3048),
#  (('xe2x99xaa', 'nothing'), 3037),
#  (('ensure', 'complete'), 3020),
#  (('tremfyantxc2xae', 'with'), 3005),
#  (('including', 'tb'), 2987),
#  (('uncontrollable', 'muscle'), 2987),
#  (('disrupts', 'my'), 2986),
#  (('you', 'xe2x99xaa'), 2982),
#  (('limu', 'emu'), 2967),
#  (('or', 'uncontrollable'), 2955),
#  (('with', 'tremfyaxc2xae'), 2941),
#  (('report', 'fever'), 2921),
#  (('line', 'activation'), 2909),
#  (('complete', 'balanced'), 2908),
#  (('plans', 'mean'), 2905),
#  (('next', 'xe2x99xaa'), 2905),
#  (('emu', 'squawks'), 2901),
#  (('air', 'strikes'), 2887),
#  (('xe2x80x94', 'they'), 2885),
#  (('xe2x80x94', 'its'), 2871),
#  (('today', 'xe2x99xaa'), 2858),
#  (('thank', 'ou'), 2850),
#  (('so', 'boost'), 2849),
#  (('otezla', 'is'), 2836),
#  (('reaction', 'serious'), 2833),
#  (('abbvie', 'can'), 2829),
#  (('champions', 'league'), 2826),
#  (('western', 'areas'), 2813),
#  (('are', 'xe2x80x94'), 2810),
#  (('gig', 'all'), 2803),
#  (('flexible', 'data'), 2803),
#  (('mobile', 'flexible'), 2800),
#  (('now', 'singers'), 2795),
#  (('balanced', 'nutrition'), 2784),
#  (('contracts', 'saving'), 2780),
#  (('internet', 'customers'), 2776),
#  (('xe2x99xaaliberty', 'liberty'), 2773),
#  (('995', 'plan'), 2766),
#  (('need', 'xe2x99xaaliberty'), 2763),
#  (('diabetes', 'dont'), 2762),
#  (('big', 'boi'), 2749),
#  (('xe2x99xaa', 'im'), 2739),
#  (('to', 'xfinity'), 2724),
#  (('chase', 'make'), 2722),
#  (('doses', 'a'), 2715),
#  (('elderly', 'dementia'), 2712),
#  (('planning', 'effect'), 2708),
#  (('shingles', 'doesnt'), 2707),
#  (('xe2x99xaa', 'no'), 2705),
#  (('fastest', 'reliable'), 2676),
#  (('xe2x80x94', 'which'), 2665),
#  (('southern', 'england'), 2657),
#  (('rinvoq', 'can'), 2655),
#  (('northern', 'scotland'), 2644),
#  (('supersonic', 'wifi'), 2639),
#  (('xe2x99xaaxe2x99xaa', 'xe2x99xaaxe2x99xaa'), 2614),
#  (('wont', 'replace'), 2613),
#  (('anncr', 'vo'), 2603),
#  (('brittney', 'griner'), 2603),
#  (('world', 'xe2x99xaa'), 2599)]
