# %%
# First let import the most necessary libs
import pandas as pd
import numpy as np
# Library to import pre-trained model for sentence embeddings
from sentence_transformers import SentenceTransformer
# Calculate similarities between sentences
from sklearn.metrics.pairwise import cosine_similarity
# Visualization library
import seaborn as sns
import matplotlib.pyplot as plt
# package for finding local minimas
from scipy.signal import argrelextrema
import math
# Out:
# /home/rm1667/.local/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)
# /projects/community/py-data-science-stack/5.1.0/kp807/envs/fastai/lib/python3.7/site-packages/sklearn/feature_extraction/image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# ...

# %%
# Loading a model - don't try it at home, it might take some time - it is 420 mb
model = SentenceTransformer('all-mpnet-base-v2')

# %%
def concatenate_sentences(sentences):
    
    # Get the length of each sentence
    sentence_lengths = [len(sentence) for sentence in sentences]
    
    # Calculate the mean and standard deviation of sentence lengths
    mean_length = np.mean(sentence_lengths)
    std_dev = np.std(sentence_lengths)
    
    # Determine the longest and shortest outliers
    long_outlier = mean_length + std_dev * 2
    short_outlier = mean_length - std_dev * 2
    
    cleaned_sentences = []
    
    for sentence in sentences:
        if len(sentence) > long_outlier:
            # Replace commas with dots in long sentences
            cleaned_sentence = sentence.replace(',', '.')
        else:
            cleaned_sentence = sentence
        
        cleaned_sentences.append(cleaned_sentence)
    
    # Concatenate the cleaned sentences
    cleaned_text = ' '.join(cleaned_sentences)
    
    return cleaned_text

# %%
def embed_sentences(text):
    print('Done')
    # Split the text into sentences
    sentences = text.split('. ')
    
    # Embed the sentences using the model
    embeddings = model.encode(sentences)
    
    return embeddings

# %%
def similarities(embeddings):
    similarities = cosine_similarity(embeddings)
    return similarities

# %%
podcast_data = pd.read_csv('Podcast/podcast_data_processed.csv')
podcast_data
# Out:
#                                        Podcast        Date  Part  \
# 0     Conservative_Review_with_Daniel_Horowitz  2022-05-12     1
# 1     Conservative_Review_with_Daniel_Horowitz  2022-02-10     1
# 2     Conservative_Review_with_Daniel_Horowitz  2022-05-16     1
# 3     Conservative_Review_with_Daniel_Horowitz  2022-09-13     1
# 4     Conservative_Review_with_Daniel_Horowitz  2022-03-14     1
# ...                                        ...         ...   ...
# 5682                       Louder_with_Crowder  2022-03-22     1
# 5683                       Louder_with_Crowder  2022-09-06    14
# 5684                       Louder_with_Crowder  2022-09-06     1
# 5685                       Louder_with_Crowder  2022-09-07     2
# 5686                       Louder_with_Crowder  2022-06-22     1
#
#                                              Transcript
# 0      And welcome back fellow American patriots and...
# 1      Set five years after Jedi Fallen Order, follo...
# ...

# %%
podcast_data['Transcript'] = podcast_data['Transcript'].apply(lambda x: x.replace("?", "."))

# %%
podcast_data['Sentences'] = podcast_data['Transcript'].apply(lambda x: x.split('. '))

# %%
podcast_data['cleaned_transcipt'] = podcast_data['Sentences'].apply(concatenate_sentences)

# %%
podcast_data['Sentences'] = podcast_data['Transcript'].apply(lambda x: x.split('. '))

# %%
podcast_data['embeddings'] = podcast_data['cleaned_transcipt'].apply(embed_sentences)
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# ...

# %%
np.savez('podcast_embeddings_pre.npz', podcast_data['embeddings'].values, allow_pickle=True)

# %%
def rev_sigmoid(x: float) -> float:
    return (1 / (1 + math.exp(0.5 * x)))

def activate_similarities(similarities: np.array, p_size=1) -> np.array:
    similarities = np.abs(similarities)  # Ensure non-negative similarities
    x = np.linspace(-10, 10, p_size)
    y = np.vectorize(rev_sigmoid)
    activation_weights = np.pad(y(x), (0, similarities.shape[0] - p_size))

    diagonals = [similarities.diagonal(each) for each in range(0, similarities.shape[0])]
    diagonals = [np.pad(each, (0, similarities.shape[0] - len(each))) for each in diagonals]
    diagonals = np.stack(diagonals)

    diagonals = diagonals * activation_weights.reshape(-1, 1)

    activated_similarities = np.sum(diagonals, axis=0)
    
    # Find relative minima using argrelextrema
    minima_indices = argrelextrema(activated_similarities, np.less, order=2)
    
    return minima_indices

# %%
podcast_data['similarities'] = podcast_data['embeddings'].apply(similarities)

# %%
podcast_data['minima'] = podcast_data['similarities'].apply(activate_similarities)

# %%
def passages_split(minmimas, sentences):
    split_points = [each for each in minmimas[0]]
    passages = []
    passage = []
    
    for num, each in enumerate(sentences):
        passage.append(each)
        if num in split_points:
            passages.append(" ".join(passage))
            passage = []
    
    if passage:
        passages.append(" ".join(passage))
    
    return passages

# %%
podcast_data['Passages'] = podcast_data.apply(lambda row: passages_split(row['minima'], row['Sentences']), axis=1)

# %%
podcast_data =podcast_data.drop(columns=['Transcript', 'embeddings', 'similarities', 'minmimas', 'minima'])

# %%
podcast_data.to_csv('Podcast/podcast_data_processed_passages.csv')
